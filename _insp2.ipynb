# %%
x_train.shape

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Jul 10 10:00:25 2024

@author: sdd380
"""
import os
cwd = os.getcwd()
if cwd.endswith('SOM_package'):
    print('Current working directory is already set to the package directory')
else:
    os.chdir('../')
    os.chdir(cwd + '/SOM_package')

from som_data_struct import som_data_struct
from som_normalize import som_normalize
from som_make import som_make
from som_bmus import som_bmus
from som_ind2sub import som_ind2sub
from som_denormalize import som_denormalize
from reader import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import copy
from sklearn.cluster import KMeans


## define dataset
filename = 'walking.csv'
filename_test = 'running.csv'

# Read data
headers = read_headers(filename)
data = read_data(filename)

# create train and test structures
sData = som_data_struct(data.copy())
sData_copy = copy.deepcopy(sData)

test_data = read_data(filename_test)
sTest = som_data_struct(test_data.copy())
sTest['comp_names'] = headers
sTest_copy = copy.deepcopy(sTest)

## Normalize the Data
plotdata = sData['data'].copy()
sData_norm = som_normalize(sData_copy, 'var')

plotdata_test = sTest['data'].copy()
sTest_norm = som_normalize(sTest_copy, 'var')
sTest_norm_copy = copy.deepcopy(sTest_norm)



## Train the SOM
sMap = som_make(sData_norm, *['lattice', 'shape', 'training'],**{'lattice':'hexa', 'shape':'sheet', 'training': 'long'})

sMap['comp_names'] = headers



## Find best-matching units
Traj_train, Qerrs_train = som_bmus(sMap, sData_norm, 'all')
Traj_train_coord = som_ind2sub(sMap, Traj_train[:,0])
Traj_train_coord = np.concatenate((Traj_train_coord, Qerrs_train[:, [0]]), axis=1)
line1 = np.concatenate((sMap['topol']['msize'], [0]))

## SOM Testing
Traj_test, Qerrs_test = som_bmus(sMap, sTest_norm_copy, 'all')
Traj_test_coord = som_ind2sub(sMap, Traj_test[:,0])
Traj_test_coord = np.concatenate((Traj_test_coord, Qerrs_test[:, [0]]), axis=1)


## Denormalize the weight vectors
M = som_denormalize(sMap['codebook'].copy(), *[sMap])

Traj_train, Qerrs_train = som_bmus(M, plotdata.copy(), 'all')
Traj_train_coord = som_ind2sub(sMap, Traj_train[:,0])
Traj_train_coord = np.concatenate((Traj_train_coord, Qerrs_train[:, [0]]), axis=1)

Traj_test, Qerrs_test = som_bmus(M, plotdata_test.copy(), 'all')
Traj_test_coord = som_ind2sub(sMap, Traj_test[:,0])
Traj_test_coord = np.concatenate((Traj_test_coord, Qerrs_test[:, [0]]), axis=1)

breakpoint()

## index all input vectors assigned to one neuron
# find the lines that hit each neuron
index = [[None for _ in range(line1[1])] for _ in range(line1[0])]

# Iterate over t and q using nested loops
for t in range(0, line1[1]):
    for q in range(0, line1[0]):
        index[q][t] = np.where((Traj_train_coord[:, 0] == q) & (Traj_train_coord[:, 1] == t))[0]


# Compute average Frame number per neuron
# Flatten index using list comprehension
index_reQE = [item for sublist in index for item in sublist]
# Number of frames (t)
num_repeats = len(plotdata) // 101

## Create a linearly spaced vector from 1 to 101
frame = np.linspace(1, 202, 202)
FRAMES = np.tile(frame, (num_repeats, 1)).flatten()
FRAMES = FRAMES.reshape(-1, 1)

FRAMES_SOM1 = np.zeros((len(M), 1))
for r in range(len(M)):
   FRAMES_SOM1[r, 0] = np.mean(FRAMES[index_reQE[r]])

FRAMES_re = FRAMES_SOM1.reshape(line1[0], line1[1])

extent = [0, FRAMES_re.shape[0], 0, FRAMES_re.shape[1]]

plt.figure(figsize=(10, 8))
plt.imshow(FRAMES_re, aspect='auto', cmap='viridis', origin='lower', extent=extent)
plt.colorbar(label='Gait cycle (%)')
plt.xlabel('X Coordinate SOM')
plt.ylabel('Y Coordinate SOM')
plt.title('2D Heatmap of FRAMES together with the Trajectories')
breakpoint()

## EXPLORE THE MAP
x_train = np.reshape(Traj_train_coord[:, 0], (101, -1), order='F')
y_train = np.reshape(Traj_train_coord[:, 1], (101, -1), order='F') 
MEAN_train = np.column_stack((np.round(np.mean(x_train, axis=1)), np.round(np.mean(y_train, axis=1))))
STD_train = np.column_stack((np.round(np.std(x_train, axis=1)), np.round(np.std(y_train, axis=1))))

x_test = np.reshape(Traj_test_coord[:, 0], (101, -1), order='F')
y_test = np.reshape(Traj_test_coord[:, 1], (101, -1), order='F')
MEAN_test = np.column_stack((np.round(np.mean(x_test, axis=1)), np.round(np.mean(y_test, axis=1))))
STD_test = np.column_stack((np.round(np.std(x_test, axis=1)), np.round(np.std(y_test, axis=1))))



marker_sizes = np.ones(101) * 10  # Initialize all markers to size 10
marker_sizes[0] = 20  # Make the first marker larger

print(f"MEAN_train range: X({MEAN_train[:, 0].min()} to {MEAN_train[:, 0].max()}), Y({MEAN_train[:, 1].min()} to {MEAN_train[:, 1].max()})")
print(f"MEAN_test range: X({MEAN_test[:, 0].min()} to {MEAN_test[:, 0].max()}), Y({MEAN_test[:, 1].min()} to {MEAN_test[:, 1].max()})")
print(f"FRAMES_re shape: {FRAMES_re.shape}")

# Define the extent based on the actual data ranges
extent = [0, FRAMES_re.shape[0], 0, FRAMES_re.shape[1]]

plt.figure(figsize=(10, 8))
plt.imshow(FRAMES_re, aspect='auto', cmap='viridis', origin='lower', extent=extent)
plt.colorbar(label='Gait cycle (%)')
plt.xlabel('X Coordinate SOM')
plt.ylabel('Y Coordinate SOM')
plt.title('2D Heatmap of FRAMES together with the Trajectories')

# Plot MEAN_train and MEAN_test with error bars
for i in range(101):
    if i == 0:
        plt.errorbar(MEAN_train[i, 0], MEAN_train[i, 1], xerr=STD_train[i, 0], yerr=STD_train[i, 1], fmt='none', ecolor='b', label='MEAN_train')
        plt.errorbar(MEAN_test[i, 0], MEAN_test[i, 1], xerr=STD_test[i, 0], yerr=STD_test[i, 1], fmt='none', ecolor='r', label='MEAN_test')
        plt.plot(MEAN_train[i, 0], MEAN_train[i, 1], 'bo', markersize=marker_sizes[i])
        plt.plot(MEAN_test[i, 0], MEAN_test[i, 1], 'ro', markersize=marker_sizes[i])
    else:
        plt.errorbar(MEAN_train[i, 0], MEAN_train[i, 1], xerr=STD_train[i, 0], yerr=STD_train[i, 1], fmt='none', ecolor='b')
        plt.errorbar(MEAN_test[i, 0], MEAN_test[i, 1], xerr=STD_test[i, 0], yerr=STD_test[i, 1], fmt='none', ecolor='r')
        plt.plot(MEAN_train[i, 0], MEAN_train[i, 1], 'bo', markersize=marker_sizes[i])
        plt.plot(MEAN_test[i, 0], MEAN_test[i, 1], 'ro', markersize=marker_sizes[i])

# Set aspect ratio to be equal
plt.gca().set_aspect('equal', adjustable='box')

plt.legend()
plt.show()
breakpoint()

## MOVEMENT DEVIATION PROFILE
# here the aim is to find the difference in Quantization Errors of the train and the test set
# relative to the SOM. These errors are then compared and illustrated into the so-called Movement 
# Deviation Profile (MDP)

# Reshape the first column of Traj_train
error_train = np.reshape(Traj_train_coord[:, 2], (101, -1), order='F')
MEAN_error_train = np.mean(error_train,axis=1)
STD_error_train = np.std(error_train, axis=1)


error_test = np.reshape(Traj_test_coord[:, 2], (101, -1), order='F')
MEAN_error_test = np.mean(error_test,axis=1)
STD_error_test = np.std(error_test, axis=1)

x = np.arange(1, 102)
y = STD_error_train
# Create the plot
plt.figure()
p1, = plt.plot(x, MEAN_error_train, 'k', linewidth=4, label='train Mean')
plt.fill_between(x, MEAN_error_train - y , MEAN_error_train + y, color=[0.6, 0.7, 0.8], alpha=0.2)
p2, = plt.plot(x, MEAN_error_test, 'r', label='test_MEAN')

plt.xlim([1, 101])
plt.xlabel('Gait Cycle (%)')
plt.ylabel('Quantization Error')
plt.legend()

plt.show()

breakpoint()

### CLUSTER the data based on the bmus
data1 = np.reshape(Traj_train_coord[:,0:3],(684, 101,3))
data2 = np.reshape(Traj_test_coord[:,0:3],(168, 101,3))

# Combine data along the first axis (vertical concatenation)
combined_data = np.concatenate((data1, data2), axis=0)

# Reshape data for clustering
flattened_data = combined_data.reshape(combined_data.shape[0], -1)

# Initialize K-means model
kmeans = KMeans(n_clusters=2, random_state=0)

# Fit K-means model to flattened data
kmeans.fit(flattened_data)

# Get cluster labels
cluster_labels = kmeans.labels_

# Separate indices of data1 and data2
num_data1 = data1.shape[0]
num_data2 = data2.shape[0]

# Create arrays to store indices of data1 and data2 in each cluster
data1_clusters = np.zeros(num_data1, dtype=int)  # Array to store cluster labels for data1
data2_clusters = np.zeros(num_data2, dtype=int)  # Array to store cluster labels for data2

# Assign cluster labels to data1
data1_clusters[cluster_labels[:num_data1] == 0] = 1  # Assign cluster 1 to trajectories in data1
data1_clusters[cluster_labels[:num_data1] == 1] = 2  # Assign cluster 2 to trajectories in data1

# Assign cluster labels to data2
data2_clusters[cluster_labels[num_data1:] == 0] = 1  # Assign cluster 1 to trajectories in data2
data2_clusters[cluster_labels[num_data1:] == 1] = 2  # Assign cluster 2 to trajectories in data2

# Combine the cluster labels into a single array
cluster_assignment = np.concatenate((data1_clusters, data2_clusters))

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot data1 trajectories
for i in range(num_data1):
    if cluster_assignment[i] == 1:
        ax.plot(data1[i, :, 0], data1[i, :, 1], data1[i, :, 2], color='blue', alpha=0.5, label='Cluster 1' if i == 0 else '')
    elif cluster_assignment[i] == 2:
        ax.plot(data1[i, :, 0], data1[i, :, 1], data1[i, :, 2], color='red', alpha=0.5, label='Cluster 2' if i == 0 else '')

# Plot data2 trajectories
for i in range(num_data2):
    index = i + num_data1
    if cluster_assignment[index] == 1:
        ax.plot(data2[i, :, 0], data2[i, :, 1], data2[i, :, 2], color='red', alpha=0.5, label='Cluster 2' if i == 0 else '')
    elif cluster_assignment[index] == 2:
        ax.plot(data2[i, :, 0], data2[i, :, 1], data2[i, :, 2], color='red', alpha=0.5, label='Cluster 2' if i == 0 else '')

plt.title('3D Clustered Trajectories')
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Quantization Error')
plt.legend()
plt.grid(True)
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys())
plt.show()

# Print the cluster assignments (just for demonstration)
print("Cluster assignments:")
for i in range(len(cluster_assignment)):
    if i < num_data1:
        print(f"Data1 slice {i} is in Cluster {cluster_assignment[i]}")
    else:
        print(f"Data2 slice {i - num_data1} is in Cluster {cluster_assignment[i]}")
# Out:
# Determining map size...
#  sTopol first round done
# Map size [44, 30]
# Initialization...
#  sTopol first round done
# Training using batch algorithm...
# Rough training phase...
# Training: 1 / 4 s
# Training: 2 / 5 s
# Training: 4 / 5 s
# Training: 5 / 5 s
# finetuning phase...
# Training: 1 / 4 s
# Training: 2 / 5 s
# Training: 4 / 5 s
# Training: 5 / 5 s
# Final quantization error: 0.785
# Final topographic error:  0.054
# c:\Users\Tijn\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Tijn\anaconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# MEAN_train range: X(12.0 to 26.0), Y(3.0 to 26.0)
# MEAN_test range: X(20.0 to 37.0), Y(3.0 to 29.0)
# FRAMES_re shape: (44, 30)
# c:\Users\Tijn\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Tijn\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# Cluster assignments:
# Data1 slice 0 is in Cluster 2
# Data1 slice 1 is in Cluster 2
# Data1 slice 2 is in Cluster 2
# Data1 slice 3 is in Cluster 2
# Data1 slice 4 is in Cluster 2
# Data1 slice 5 is in Cluster 2
# Data1 slice 6 is in Cluster 2
# Data1 slice 7 is in Cluster 2
# Data1 slice 8 is in Cluster 2
# Data1 slice 9 is in Cluster 2
# Data1 slice 10 is in Cluster 2
# Data1 slice 11 is in Cluster 2
# Data1 slice 12 is in Cluster 2
# Data1 slice 13 is in Cluster 2
# Data1 slice 14 is in Cluster 2
# Data1 slice 15 is in Cluster 2
# Data1 slice 16 is in Cluster 2
# Data1 slice 17 is in Cluster 2
# Data1 slice 18 is in Cluster 2
# Data1 slice 19 is in Cluster 2
# Data1 slice 20 is in Cluster 2
# Data1 slice 21 is in Cluster 2
# Data1 slice 22 is in Cluster 2
# Data1 slice 23 is in Cluster 2
# Data1 slice 24 is in Cluster 2
# Data1 slice 25 is in Cluster 2
# Data1 slice 26 is in Cluster 2
# Data1 slice 27 is in Cluster 2
# Data1 slice 28 is in Cluster 2
# Data1 slice 29 is in Cluster 2
# Data1 slice 30 is in Cluster 2
# Data1 slice 31 is in Cluster 2
# Data1 slice 32 is in Cluster 2
# Data1 slice 33 is in Cluster 2
# Data1 slice 34 is in Cluster 2
# Data1 slice 35 is in Cluster 2
# Data1 slice 36 is in Cluster 2
# Data1 slice 37 is in Cluster 2
# Data1 slice 38 is in Cluster 2
# Data1 slice 39 is in Cluster 2
# Data1 slice 40 is in Cluster 2
# Data1 slice 41 is in Cluster 2
# Data1 slice 42 is in Cluster 2
# Data1 slice 43 is in Cluster 2
# Data1 slice 44 is in Cluster 2
# Data1 slice 45 is in Cluster 2
# Data1 slice 46 is in Cluster 2
# Data1 slice 47 is in Cluster 2
# Data1 slice 48 is in Cluster 2
# Data1 slice 49 is in Cluster 2
# Data1 slice 50 is in Cluster 2
# Data1 slice 51 is in Cluster 2
# Data1 slice 52 is in Cluster 2
# Data1 slice 53 is in Cluster 2
# Data1 slice 54 is in Cluster 2
# Data1 slice 55 is in Cluster 2
# Data1 slice 56 is in Cluster 2
# Data1 slice 57 is in Cluster 2
# Data1 slice 58 is in Cluster 2
# Data1 slice 59 is in Cluster 2
# Data1 slice 60 is in Cluster 2
# Data1 slice 61 is in Cluster 2
# Data1 slice 62 is in Cluster 2
# Data1 slice 63 is in Cluster 2
# Data1 slice 64 is in Cluster 2
# Data1 slice 65 is in Cluster 2
# Data1 slice 66 is in Cluster 2
# Data1 slice 67 is in Cluster 2
# Data1 slice 68 is in Cluster 2
# Data1 slice 69 is in Cluster 2
# Data1 slice 70 is in Cluster 2
# Data1 slice 71 is in Cluster 2
# Data1 slice 72 is in Cluster 2
# Data1 slice 73 is in Cluster 2
# Data1 slice 74 is in Cluster 2
# Data1 slice 75 is in Cluster 2
# Data1 slice 76 is in Cluster 2
# Data1 slice 77 is in Cluster 2
# Data1 slice 78 is in Cluster 2
# Data1 slice 79 is in Cluster 2
# Data1 slice 80 is in Cluster 2
# Data1 slice 81 is in Cluster 2
# Data1 slice 82 is in Cluster 2
# Data1 slice 83 is in Cluster 2
# Data1 slice 84 is in Cluster 2
# Data1 slice 85 is in Cluster 2
# Data1 slice 86 is in Cluster 2
# Data1 slice 87 is in Cluster 2
# Data1 slice 88 is in Cluster 2
# Data1 slice 89 is in Cluster 2
# Data1 slice 90 is in Cluster 2
# Data1 slice 91 is in Cluster 2
# Data1 slice 92 is in Cluster 2
# Data1 slice 93 is in Cluster 2
# Data1 slice 94 is in Cluster 2
# Data1 slice 95 is in Cluster 2
# Data1 slice 96 is in Cluster 2
# Data1 slice 97 is in Cluster 2
# Data1 slice 98 is in Cluster 2
# Data1 slice 99 is in Cluster 2
# Data1 slice 100 is in Cluster 2
# Data1 slice 101 is in Cluster 2
# Data1 slice 102 is in Cluster 2
# Data1 slice 103 is in Cluster 2
# Data1 slice 104 is in Cluster 2
# Data1 slice 105 is in Cluster 2
# Data1 slice 106 is in Cluster 2
# Data1 slice 107 is in Cluster 2
# Data1 slice 108 is in Cluster 2
# Data1 slice 109 is in Cluster 2
# Data1 slice 110 is in Cluster 2
# Data1 slice 111 is in Cluster 2
# Data1 slice 112 is in Cluster 2
# Data1 slice 113 is in Cluster 2
# Data1 slice 114 is in Cluster 2
# Data1 slice 115 is in Cluster 2
# Data1 slice 116 is in Cluster 2
# Data1 slice 117 is in Cluster 2
# Data1 slice 118 is in Cluster 2
# Data1 slice 119 is in Cluster 2
# Data1 slice 120 is in Cluster 2
# Data1 slice 121 is in Cluster 2
# Data1 slice 122 is in Cluster 2
# Data1 slice 123 is in Cluster 2
# Data1 slice 124 is in Cluster 2
# Data1 slice 125 is in Cluster 2
# Data1 slice 126 is in Cluster 2
# Data1 slice 127 is in Cluster 2
# Data1 slice 128 is in Cluster 2
# Data1 slice 129 is in Cluster 2
# Data1 slice 130 is in Cluster 2
# Data1 slice 131 is in Cluster 2
# Data1 slice 132 is in Cluster 2
# Data1 slice 133 is in Cluster 2
# Data1 slice 134 is in Cluster 2
# Data1 slice 135 is in Cluster 2
# Data1 slice 136 is in Cluster 2
# Data1 slice 137 is in Cluster 2
# Data1 slice 138 is in Cluster 2
# Data1 slice 139 is in Cluster 2
# Data1 slice 140 is in Cluster 2
# Data1 slice 141 is in Cluster 2
# Data1 slice 142 is in Cluster 2
# Data1 slice 143 is in Cluster 2
# Data1 slice 144 is in Cluster 2
# Data1 slice 145 is in Cluster 2
# Data1 slice 146 is in Cluster 2
# Data1 slice 147 is in Cluster 2
# Data1 slice 148 is in Cluster 2
# Data1 slice 149 is in Cluster 2
# Data1 slice 150 is in Cluster 2
# Data1 slice 151 is in Cluster 2
# Data1 slice 152 is in Cluster 2
# Data1 slice 153 is in Cluster 2
# Data1 slice 154 is in Cluster 2
# Data1 slice 155 is in Cluster 2
# Data1 slice 156 is in Cluster 2
# Data1 slice 157 is in Cluster 2
# Data1 slice 158 is in Cluster 2
# Data1 slice 159 is in Cluster 2
# Data1 slice 160 is in Cluster 2
# Data1 slice 161 is in Cluster 2
# Data1 slice 162 is in Cluster 2
# Data1 slice 163 is in Cluster 2
# Data1 slice 164 is in Cluster 2
# Data1 slice 165 is in Cluster 2
# Data1 slice 166 is in Cluster 2
# Data1 slice 167 is in Cluster 2
# Data1 slice 168 is in Cluster 2
# Data1 slice 169 is in Cluster 2
# Data1 slice 170 is in Cluster 2
# Data1 slice 171 is in Cluster 2
# Data1 slice 172 is in Cluster 2
# Data1 slice 173 is in Cluster 2
# Data1 slice 174 is in Cluster 2
# Data1 slice 175 is in Cluster 2
# Data1 slice 176 is in Cluster 2
# Data1 slice 177 is in Cluster 2
# Data1 slice 178 is in Cluster 2
# Data1 slice 179 is in Cluster 2
# Data1 slice 180 is in Cluster 2
# Data1 slice 181 is in Cluster 2
# Data1 slice 182 is in Cluster 2
# Data1 slice 183 is in Cluster 2
# Data1 slice 184 is in Cluster 2
# Data1 slice 185 is in Cluster 2
# Data1 slice 186 is in Cluster 2
# Data1 slice 187 is in Cluster 2
# Data1 slice 188 is in Cluster 2
# Data1 slice 189 is in Cluster 2
# Data1 slice 190 is in Cluster 2
# Data1 slice 191 is in Cluster 2
# Data1 slice 192 is in Cluster 2
# Data1 slice 193 is in Cluster 2
# Data1 slice 194 is in Cluster 2
# Data1 slice 195 is in Cluster 2
# Data1 slice 196 is in Cluster 2
# Data1 slice 197 is in Cluster 2
# Data1 slice 198 is in Cluster 2
# Data1 slice 199 is in Cluster 2
# Data1 slice 200 is in Cluster 2
# Data1 slice 201 is in Cluster 2
# Data1 slice 202 is in Cluster 2
# Data1 slice 203 is in Cluster 2
# Data1 slice 204 is in Cluster 2
# Data1 slice 205 is in Cluster 2
# Data1 slice 206 is in Cluster 2
# Data1 slice 207 is in Cluster 2
# Data1 slice 208 is in Cluster 2
# Data1 slice 209 is in Cluster 2
# Data1 slice 210 is in Cluster 2
# Data1 slice 211 is in Cluster 2
# Data1 slice 212 is in Cluster 2
# Data1 slice 213 is in Cluster 2
# Data1 slice 214 is in Cluster 2
# Data1 slice 215 is in Cluster 2
# Data1 slice 216 is in Cluster 2
# Data1 slice 217 is in Cluster 2
# Data1 slice 218 is in Cluster 2
# Data1 slice 219 is in Cluster 2
# Data1 slice 220 is in Cluster 2
# Data1 slice 221 is in Cluster 2
# Data1 slice 222 is in Cluster 2
# Data1 slice 223 is in Cluster 2
# Data1 slice 224 is in Cluster 2
# Data1 slice 225 is in Cluster 2
# Data1 slice 226 is in Cluster 2
# Data1 slice 227 is in Cluster 2
# Data1 slice 228 is in Cluster 2
# Data1 slice 229 is in Cluster 2
# Data1 slice 230 is in Cluster 2
# Data1 slice 231 is in Cluster 2
# Data1 slice 232 is in Cluster 2
# Data1 slice 233 is in Cluster 2
# Data1 slice 234 is in Cluster 2
# Data1 slice 235 is in Cluster 2
# Data1 slice 236 is in Cluster 2
# Data1 slice 237 is in Cluster 2
# Data1 slice 238 is in Cluster 2
# Data1 slice 239 is in Cluster 2
# Data1 slice 240 is in Cluster 2
# Data1 slice 241 is in Cluster 2
# Data1 slice 242 is in Cluster 2
# Data1 slice 243 is in Cluster 2
# Data1 slice 244 is in Cluster 2
# Data1 slice 245 is in Cluster 2
# Data1 slice 246 is in Cluster 2
# Data1 slice 247 is in Cluster 2
# Data1 slice 248 is in Cluster 2
# Data1 slice 249 is in Cluster 2
# Data1 slice 250 is in Cluster 2
# Data1 slice 251 is in Cluster 2
# Data1 slice 252 is in Cluster 2
# Data1 slice 253 is in Cluster 2
# Data1 slice 254 is in Cluster 2
# Data1 slice 255 is in Cluster 2
# Data1 slice 256 is in Cluster 2
# Data1 slice 257 is in Cluster 2
# Data1 slice 258 is in Cluster 2
# Data1 slice 259 is in Cluster 2
# Data1 slice 260 is in Cluster 2
# Data1 slice 261 is in Cluster 2
# Data1 slice 262 is in Cluster 2
# Data1 slice 263 is in Cluster 2
# Data1 slice 264 is in Cluster 2
# Data1 slice 265 is in Cluster 2
# Data1 slice 266 is in Cluster 2
# Data1 slice 267 is in Cluster 2
# Data1 slice 268 is in Cluster 2
# Data1 slice 269 is in Cluster 2
# Data1 slice 270 is in Cluster 2
# Data1 slice 271 is in Cluster 2
# Data1 slice 272 is in Cluster 2
# Data1 slice 273 is in Cluster 2
# Data1 slice 274 is in Cluster 2
# Data1 slice 275 is in Cluster 2
# Data1 slice 276 is in Cluster 2
# Data1 slice 277 is in Cluster 2
# Data1 slice 278 is in Cluster 2
# Data1 slice 279 is in Cluster 2
# Data1 slice 280 is in Cluster 2
# Data1 slice 281 is in Cluster 2
# Data1 slice 282 is in Cluster 2
# Data1 slice 283 is in Cluster 2
# Data1 slice 284 is in Cluster 2
# Data1 slice 285 is in Cluster 2
# Data1 slice 286 is in Cluster 2
# Data1 slice 287 is in Cluster 2
# Data1 slice 288 is in Cluster 2
# Data1 slice 289 is in Cluster 2
# Data1 slice 290 is in Cluster 2
# Data1 slice 291 is in Cluster 2
# Data1 slice 292 is in Cluster 2
# Data1 slice 293 is in Cluster 2
# Data1 slice 294 is in Cluster 2
# Data1 slice 295 is in Cluster 2
# Data1 slice 296 is in Cluster 2
# Data1 slice 297 is in Cluster 2
# Data1 slice 298 is in Cluster 2
# Data1 slice 299 is in Cluster 2
# Data1 slice 300 is in Cluster 2
# Data1 slice 301 is in Cluster 2
# Data1 slice 302 is in Cluster 2
# Data1 slice 303 is in Cluster 2
# Data1 slice 304 is in Cluster 2
# Data1 slice 305 is in Cluster 2
# Data1 slice 306 is in Cluster 2
# Data1 slice 307 is in Cluster 2
# Data1 slice 308 is in Cluster 2
# Data1 slice 309 is in Cluster 2
# Data1 slice 310 is in Cluster 2
# Data1 slice 311 is in Cluster 2
# Data1 slice 312 is in Cluster 2
# Data1 slice 313 is in Cluster 2
# Data1 slice 314 is in Cluster 2
# Data1 slice 315 is in Cluster 2
# Data1 slice 316 is in Cluster 2
# Data1 slice 317 is in Cluster 2
# Data1 slice 318 is in Cluster 2
# Data1 slice 319 is in Cluster 2
# Data1 slice 320 is in Cluster 2
# Data1 slice 321 is in Cluster 2
# Data1 slice 322 is in Cluster 2
# Data1 slice 323 is in Cluster 2
# Data1 slice 324 is in Cluster 2
# Data1 slice 325 is in Cluster 2
# Data1 slice 326 is in Cluster 2
# Data1 slice 327 is in Cluster 2
# Data1 slice 328 is in Cluster 2
# Data1 slice 329 is in Cluster 2
# Data1 slice 330 is in Cluster 2
# Data1 slice 331 is in Cluster 2
# Data1 slice 332 is in Cluster 2
# Data1 slice 333 is in Cluster 2
# Data1 slice 334 is in Cluster 2
# Data1 slice 335 is in Cluster 2
# Data1 slice 336 is in Cluster 2
# Data1 slice 337 is in Cluster 2
# Data1 slice 338 is in Cluster 2
# Data1 slice 339 is in Cluster 2
# Data1 slice 340 is in Cluster 2
# Data1 slice 341 is in Cluster 2
# Data1 slice 342 is in Cluster 2
# Data1 slice 343 is in Cluster 2
# Data1 slice 344 is in Cluster 2
# Data1 slice 345 is in Cluster 2
# Data1 slice 346 is in Cluster 2
# Data1 slice 347 is in Cluster 2
# Data1 slice 348 is in Cluster 2
# Data1 slice 349 is in Cluster 2
# Data1 slice 350 is in Cluster 2
# Data1 slice 351 is in Cluster 2
# Data1 slice 352 is in Cluster 2
# Data1 slice 353 is in Cluster 2
# Data1 slice 354 is in Cluster 2
# Data1 slice 355 is in Cluster 2
# Data1 slice 356 is in Cluster 2
# Data1 slice 357 is in Cluster 2
# Data1 slice 358 is in Cluster 2
# Data1 slice 359 is in Cluster 2
# Data1 slice 360 is in Cluster 2
# Data1 slice 361 is in Cluster 2
# Data1 slice 362 is in Cluster 2
# Data1 slice 363 is in Cluster 2
# Data1 slice 364 is in Cluster 2
# Data1 slice 365 is in Cluster 2
# Data1 slice 366 is in Cluster 2
# Data1 slice 367 is in Cluster 2
# Data1 slice 368 is in Cluster 2
# Data1 slice 369 is in Cluster 2
# Data1 slice 370 is in Cluster 2
# Data1 slice 371 is in Cluster 2
# Data1 slice 372 is in Cluster 2
# Data1 slice 373 is in Cluster 2
# Data1 slice 374 is in Cluster 2
# Data1 slice 375 is in Cluster 2
# Data1 slice 376 is in Cluster 2
# Data1 slice 377 is in Cluster 2
# Data1 slice 378 is in Cluster 2
# Data1 slice 379 is in Cluster 2
# Data1 slice 380 is in Cluster 2
# Data1 slice 381 is in Cluster 2
# Data1 slice 382 is in Cluster 2
# Data1 slice 383 is in Cluster 2
# Data1 slice 384 is in Cluster 2
# Data1 slice 385 is in Cluster 2
# Data1 slice 386 is in Cluster 2
# Data1 slice 387 is in Cluster 2
# Data1 slice 388 is in Cluster 2
# Data1 slice 389 is in Cluster 2
# Data1 slice 390 is in Cluster 2
# Data1 slice 391 is in Cluster 2
# Data1 slice 392 is in Cluster 2
# Data1 slice 393 is in Cluster 2
# Data1 slice 394 is in Cluster 2
# Data1 slice 395 is in Cluster 2
# Data1 slice 396 is in Cluster 2
# Data1 slice 397 is in Cluster 2
# Data1 slice 398 is in Cluster 2
# Data1 slice 399 is in Cluster 2
# Data1 slice 400 is in Cluster 2
# Data1 slice 401 is in Cluster 2
# Data1 slice 402 is in Cluster 2
# Data1 slice 403 is in Cluster 2
# Data1 slice 404 is in Cluster 2
# Data1 slice 405 is in Cluster 2
# Data1 slice 406 is in Cluster 2
# Data1 slice 407 is in Cluster 2
# Data1 slice 408 is in Cluster 2
# Data1 slice 409 is in Cluster 2
# Data1 slice 410 is in Cluster 2
# Data1 slice 411 is in Cluster 2
# Data1 slice 412 is in Cluster 2
# Data1 slice 413 is in Cluster 2
# Data1 slice 414 is in Cluster 2
# Data1 slice 415 is in Cluster 2
# Data1 slice 416 is in Cluster 2
# Data1 slice 417 is in Cluster 2
# Data1 slice 418 is in Cluster 2
# Data1 slice 419 is in Cluster 2
# Data1 slice 420 is in Cluster 2
# Data1 slice 421 is in Cluster 2
# Data1 slice 422 is in Cluster 2
# Data1 slice 423 is in Cluster 2
# Data1 slice 424 is in Cluster 2
# Data1 slice 425 is in Cluster 2
# Data1 slice 426 is in Cluster 2
# Data1 slice 427 is in Cluster 2
# Data1 slice 428 is in Cluster 2
# Data1 slice 429 is in Cluster 2
# Data1 slice 430 is in Cluster 2
# Data1 slice 431 is in Cluster 2
# Data1 slice 432 is in Cluster 2
# Data1 slice 433 is in Cluster 2
# Data1 slice 434 is in Cluster 2
# Data1 slice 435 is in Cluster 2
# Data1 slice 436 is in Cluster 2
# Data1 slice 437 is in Cluster 2
# Data1 slice 438 is in Cluster 2
# Data1 slice 439 is in Cluster 2
# Data1 slice 440 is in Cluster 2
# Data1 slice 441 is in Cluster 2
# Data1 slice 442 is in Cluster 2
# Data1 slice 443 is in Cluster 2
# Data1 slice 444 is in Cluster 2
# Data1 slice 445 is in Cluster 2
# Data1 slice 446 is in Cluster 2
# Data1 slice 447 is in Cluster 2
# Data1 slice 448 is in Cluster 2
# Data1 slice 449 is in Cluster 2
# Data1 slice 450 is in Cluster 2
# Data1 slice 451 is in Cluster 2
# Data1 slice 452 is in Cluster 2
# Data1 slice 453 is in Cluster 2
# Data1 slice 454 is in Cluster 2
# Data1 slice 455 is in Cluster 2
# Data1 slice 456 is in Cluster 2
# Data1 slice 457 is in Cluster 2
# Data1 slice 458 is in Cluster 2
# Data1 slice 459 is in Cluster 2
# Data1 slice 460 is in Cluster 2
# Data1 slice 461 is in Cluster 2
# Data1 slice 462 is in Cluster 2
# Data1 slice 463 is in Cluster 2
# Data1 slice 464 is in Cluster 2
# Data1 slice 465 is in Cluster 2
# Data1 slice 466 is in Cluster 2
# Data1 slice 467 is in Cluster 2
# Data1 slice 468 is in Cluster 2
# Data1 slice 469 is in Cluster 2
# Data1 slice 470 is in Cluster 2
# Data1 slice 471 is in Cluster 2
# Data1 slice 472 is in Cluster 2
# Data1 slice 473 is in Cluster 2
# Data1 slice 474 is in Cluster 2
# Data1 slice 475 is in Cluster 2
# Data1 slice 476 is in Cluster 2
# Data1 slice 477 is in Cluster 2
# Data1 slice 478 is in Cluster 2
# Data1 slice 479 is in Cluster 2
# Data1 slice 480 is in Cluster 2
# Data1 slice 481 is in Cluster 2
# Data1 slice 482 is in Cluster 2
# Data1 slice 483 is in Cluster 2
# Data1 slice 484 is in Cluster 2
# Data1 slice 485 is in Cluster 2
# Data1 slice 486 is in Cluster 2
# Data1 slice 487 is in Cluster 2
# Data1 slice 488 is in Cluster 2
# Data1 slice 489 is in Cluster 2
# Data1 slice 490 is in Cluster 2
# Data1 slice 491 is in Cluster 2
# Data1 slice 492 is in Cluster 2
# Data1 slice 493 is in Cluster 2
# Data1 slice 494 is in Cluster 2
# Data1 slice 495 is in Cluster 2
# Data1 slice 496 is in Cluster 2
# Data1 slice 497 is in Cluster 2
# Data1 slice 498 is in Cluster 2
# Data1 slice 499 is in Cluster 2
# Data1 slice 500 is in Cluster 2
# Data1 slice 501 is in Cluster 2
# Data1 slice 502 is in Cluster 2
# Data1 slice 503 is in Cluster 2
# Data1 slice 504 is in Cluster 2
# Data1 slice 505 is in Cluster 2
# Data1 slice 506 is in Cluster 2
# Data1 slice 507 is in Cluster 2
# Data1 slice 508 is in Cluster 2
# Data1 slice 509 is in Cluster 2
# Data1 slice 510 is in Cluster 2
# Data1 slice 511 is in Cluster 2
# Data1 slice 512 is in Cluster 2
# Data1 slice 513 is in Cluster 2
# Data1 slice 514 is in Cluster 2
# Data1 slice 515 is in Cluster 2
# Data1 slice 516 is in Cluster 2
# Data1 slice 517 is in Cluster 2
# Data1 slice 518 is in Cluster 2
# Data1 slice 519 is in Cluster 2
# Data1 slice 520 is in Cluster 2
# Data1 slice 521 is in Cluster 2
# Data1 slice 522 is in Cluster 2
# Data1 slice 523 is in Cluster 2
# Data1 slice 524 is in Cluster 2
# Data1 slice 525 is in Cluster 2
# Data1 slice 526 is in Cluster 2
# Data1 slice 527 is in Cluster 2
# Data1 slice 528 is in Cluster 2
# Data1 slice 529 is in Cluster 2
# Data1 slice 530 is in Cluster 2
# Data1 slice 531 is in Cluster 2
# Data1 slice 532 is in Cluster 2
# Data1 slice 533 is in Cluster 2
# Data1 slice 534 is in Cluster 2
# Data1 slice 535 is in Cluster 2
# Data1 slice 536 is in Cluster 2
# Data1 slice 537 is in Cluster 2
# Data1 slice 538 is in Cluster 2
# Data1 slice 539 is in Cluster 2
# Data1 slice 540 is in Cluster 2
# Data1 slice 541 is in Cluster 2
# Data1 slice 542 is in Cluster 2
# Data1 slice 543 is in Cluster 2
# Data1 slice 544 is in Cluster 2
# Data1 slice 545 is in Cluster 2
# Data1 slice 546 is in Cluster 2
# Data1 slice 547 is in Cluster 2
# Data1 slice 548 is in Cluster 2
# Data1 slice 549 is in Cluster 2
# Data1 slice 550 is in Cluster 2
# Data1 slice 551 is in Cluster 2
# Data1 slice 552 is in Cluster 2
# Data1 slice 553 is in Cluster 2
# Data1 slice 554 is in Cluster 2
# Data1 slice 555 is in Cluster 2
# Data1 slice 556 is in Cluster 2
# Data1 slice 557 is in Cluster 2
# Data1 slice 558 is in Cluster 2
# Data1 slice 559 is in Cluster 2
# Data1 slice 560 is in Cluster 2
# Data1 slice 561 is in Cluster 2
# Data1 slice 562 is in Cluster 2
# Data1 slice 563 is in Cluster 2
# Data1 slice 564 is in Cluster 2
# Data1 slice 565 is in Cluster 2
# Data1 slice 566 is in Cluster 2
# Data1 slice 567 is in Cluster 2
# Data1 slice 568 is in Cluster 2
# Data1 slice 569 is in Cluster 2
# Data1 slice 570 is in Cluster 2
# Data1 slice 571 is in Cluster 2
# Data1 slice 572 is in Cluster 2
# Data1 slice 573 is in Cluster 2
# Data1 slice 574 is in Cluster 2
# Data1 slice 575 is in Cluster 2
# Data1 slice 576 is in Cluster 2
# Data1 slice 577 is in Cluster 2
# Data1 slice 578 is in Cluster 2
# Data1 slice 579 is in Cluster 2
# Data1 slice 580 is in Cluster 2
# Data1 slice 581 is in Cluster 2
# Data1 slice 582 is in Cluster 2
# Data1 slice 583 is in Cluster 2
# Data1 slice 584 is in Cluster 2
# Data1 slice 585 is in Cluster 2
# Data1 slice 586 is in Cluster 2
# Data1 slice 587 is in Cluster 2
# Data1 slice 588 is in Cluster 2
# Data1 slice 589 is in Cluster 2
# Data1 slice 590 is in Cluster 2
# Data1 slice 591 is in Cluster 2
# Data1 slice 592 is in Cluster 2
# Data1 slice 593 is in Cluster 2
# Data1 slice 594 is in Cluster 2
# Data1 slice 595 is in Cluster 2
# Data1 slice 596 is in Cluster 2
# Data1 slice 597 is in Cluster 2
# Data1 slice 598 is in Cluster 2
# Data1 slice 599 is in Cluster 2
# Data1 slice 600 is in Cluster 2
# Data1 slice 601 is in Cluster 2
# Data1 slice 602 is in Cluster 2
# Data1 slice 603 is in Cluster 2
# Data1 slice 604 is in Cluster 2
# Data1 slice 605 is in Cluster 2
# Data1 slice 606 is in Cluster 2
# Data1 slice 607 is in Cluster 2
# Data1 slice 608 is in Cluster 2
# Data1 slice 609 is in Cluster 2
# Data1 slice 610 is in Cluster 2
# Data1 slice 611 is in Cluster 2
# Data1 slice 612 is in Cluster 2
# Data1 slice 613 is in Cluster 2
# Data1 slice 614 is in Cluster 2
# Data1 slice 615 is in Cluster 2
# Data1 slice 616 is in Cluster 2
# Data1 slice 617 is in Cluster 2
# Data1 slice 618 is in Cluster 2
# Data1 slice 619 is in Cluster 2
# Data1 slice 620 is in Cluster 2
# Data1 slice 621 is in Cluster 2
# Data1 slice 622 is in Cluster 2
# Data1 slice 623 is in Cluster 2
# Data1 slice 624 is in Cluster 2
# Data1 slice 625 is in Cluster 2
# Data1 slice 626 is in Cluster 2
# Data1 slice 627 is in Cluster 2
# Data1 slice 628 is in Cluster 2
# Data1 slice 629 is in Cluster 2
# Data1 slice 630 is in Cluster 2
# Data1 slice 631 is in Cluster 2
# Data1 slice 632 is in Cluster 2
# Data1 slice 633 is in Cluster 2
# Data1 slice 634 is in Cluster 2
# Data1 slice 635 is in Cluster 2
# Data1 slice 636 is in Cluster 2
# Data1 slice 637 is in Cluster 2
# Data1 slice 638 is in Cluster 2
# Data1 slice 639 is in Cluster 2
# Data1 slice 640 is in Cluster 2
# Data1 slice 641 is in Cluster 2
# Data1 slice 642 is in Cluster 2
# Data1 slice 643 is in Cluster 2
# Data1 slice 644 is in Cluster 2
# Data1 slice 645 is in Cluster 2
# Data1 slice 646 is in Cluster 2
# Data1 slice 647 is in Cluster 2
# Data1 slice 648 is in Cluster 2
# Data1 slice 649 is in Cluster 2
# Data1 slice 650 is in Cluster 2
# Data1 slice 651 is in Cluster 2
# Data1 slice 652 is in Cluster 2
# Data1 slice 653 is in Cluster 2
# Data1 slice 654 is in Cluster 2
# Data1 slice 655 is in Cluster 2
# Data1 slice 656 is in Cluster 2
# Data1 slice 657 is in Cluster 2
# Data1 slice 658 is in Cluster 2
# Data1 slice 659 is in Cluster 2
# Data1 slice 660 is in Cluster 2
# Data1 slice 661 is in Cluster 2
# Data1 slice 662 is in Cluster 2
# Data1 slice 663 is in Cluster 2
# Data1 slice 664 is in Cluster 2
# Data1 slice 665 is in Cluster 2
# Data1 slice 666 is in Cluster 2
# Data1 slice 667 is in Cluster 2
# Data1 slice 668 is in Cluster 2
# Data1 slice 669 is in Cluster 2
# Data1 slice 670 is in Cluster 2
# Data1 slice 671 is in Cluster 2
# Data1 slice 672 is in Cluster 2
# Data1 slice 673 is in Cluster 2
# Data1 slice 674 is in Cluster 2
# Data1 slice 675 is in Cluster 2
# Data1 slice 676 is in Cluster 2
# Data1 slice 677 is in Cluster 2
# Data1 slice 678 is in Cluster 2
# Data1 slice 679 is in Cluster 2
# Data1 slice 680 is in Cluster 2
# Data1 slice 681 is in Cluster 2
# Data1 slice 682 is in Cluster 2
# Data1 slice 683 is in Cluster 2
# Data2 slice 0 is in Cluster 1
# Data2 slice 1 is in Cluster 1
# Data2 slice 2 is in Cluster 1
# Data2 slice 3 is in Cluster 1
# Data2 slice 4 is in Cluster 1
# Data2 slice 5 is in Cluster 1
# Data2 slice 6 is in Cluster 1
# Data2 slice 7 is in Cluster 1
# Data2 slice 8 is in Cluster 1
# Data2 slice 9 is in Cluster 1
# Data2 slice 10 is in Cluster 1
# Data2 slice 11 is in Cluster 1
# Data2 slice 12 is in Cluster 1
# Data2 slice 13 is in Cluster 1
# Data2 slice 14 is in Cluster 1
# Data2 slice 15 is in Cluster 1
# Data2 slice 16 is in Cluster 1
# Data2 slice 17 is in Cluster 1
# Data2 slice 18 is in Cluster 1
# Data2 slice 19 is in Cluster 1
# Data2 slice 20 is in Cluster 1
# Data2 slice 21 is in Cluster 1
# Data2 slice 22 is in Cluster 1
# Data2 slice 23 is in Cluster 1
# Data2 slice 24 is in Cluster 1
# Data2 slice 25 is in Cluster 1
# Data2 slice 26 is in Cluster 1
# Data2 slice 27 is in Cluster 1
# Data2 slice 28 is in Cluster 1
# Data2 slice 29 is in Cluster 1
# Data2 slice 30 is in Cluster 1
# Data2 slice 31 is in Cluster 1
# Data2 slice 32 is in Cluster 1
# Data2 slice 33 is in Cluster 1
# Data2 slice 34 is in Cluster 1
# Data2 slice 35 is in Cluster 1
# Data2 slice 36 is in Cluster 1
# Data2 slice 37 is in Cluster 1
# Data2 slice 38 is in Cluster 1
# Data2 slice 39 is in Cluster 1
# Data2 slice 40 is in Cluster 1
# Data2 slice 41 is in Cluster 1
# Data2 slice 42 is in Cluster 1
# Data2 slice 43 is in Cluster 1
# Data2 slice 44 is in Cluster 1
# Data2 slice 45 is in Cluster 1
# Data2 slice 46 is in Cluster 1
# Data2 slice 47 is in Cluster 1
# Data2 slice 48 is in Cluster 1
# Data2 slice 49 is in Cluster 1
# Data2 slice 50 is in Cluster 1
# Data2 slice 51 is in Cluster 1
# Data2 slice 52 is in Cluster 1
# Data2 slice 53 is in Cluster 1
# Data2 slice 54 is in Cluster 1
# Data2 slice 55 is in Cluster 1
# Data2 slice 56 is in Cluster 1
# Data2 slice 57 is in Cluster 1
# Data2 slice 58 is in Cluster 1
# Data2 slice 59 is in Cluster 1
# Data2 slice 60 is in Cluster 1
# Data2 slice 61 is in Cluster 1
# Data2 slice 62 is in Cluster 1
# Data2 slice 63 is in Cluster 1
# Data2 slice 64 is in Cluster 1
# Data2 slice 65 is in Cluster 1
# Data2 slice 66 is in Cluster 1
# Data2 slice 67 is in Cluster 1
# Data2 slice 68 is in Cluster 1
# Data2 slice 69 is in Cluster 1
# Data2 slice 70 is in Cluster 1
# Data2 slice 71 is in Cluster 1
# Data2 slice 72 is in Cluster 1
# Data2 slice 73 is in Cluster 1
# Data2 slice 74 is in Cluster 1
# Data2 slice 75 is in Cluster 1
# Data2 slice 76 is in Cluster 1
# Data2 slice 77 is in Cluster 1
# Data2 slice 78 is in Cluster 1
# Data2 slice 79 is in Cluster 1
# Data2 slice 80 is in Cluster 1
# Data2 slice 81 is in Cluster 1
# Data2 slice 82 is in Cluster 1
# Data2 slice 83 is in Cluster 1
# Data2 slice 84 is in Cluster 1
# Data2 slice 85 is in Cluster 1
# Data2 slice 86 is in Cluster 1
# Data2 slice 87 is in Cluster 1
# Data2 slice 88 is in Cluster 1
# Data2 slice 89 is in Cluster 1
# Data2 slice 90 is in Cluster 1
# Data2 slice 91 is in Cluster 1
# Data2 slice 92 is in Cluster 1
# Data2 slice 93 is in Cluster 1
# Data2 slice 94 is in Cluster 1
# Data2 slice 95 is in Cluster 1
# Data2 slice 96 is in Cluster 1
# Data2 slice 97 is in Cluster 1
# Data2 slice 98 is in Cluster 1
# Data2 slice 99 is in Cluster 1
# Data2 slice 100 is in Cluster 1
# Data2 slice 101 is in Cluster 1
# Data2 slice 102 is in Cluster 1
# Data2 slice 103 is in Cluster 1
# Data2 slice 104 is in Cluster 1
# Data2 slice 105 is in Cluster 1
# Data2 slice 106 is in Cluster 1
# Data2 slice 107 is in Cluster 1
# Data2 slice 108 is in Cluster 1
# Data2 slice 109 is in Cluster 1
# Data2 slice 110 is in Cluster 1
# Data2 slice 111 is in Cluster 1
# Data2 slice 112 is in Cluster 1
# Data2 slice 113 is in Cluster 1
# Data2 slice 114 is in Cluster 1
# Data2 slice 115 is in Cluster 1
# Data2 slice 116 is in Cluster 1
# Data2 slice 117 is in Cluster 1
# Data2 slice 118 is in Cluster 1
# Data2 slice 119 is in Cluster 1
# Data2 slice 120 is in Cluster 1
# Data2 slice 121 is in Cluster 1
# Data2 slice 122 is in Cluster 1
# Data2 slice 123 is in Cluster 1
# Data2 slice 124 is in Cluster 1
# Data2 slice 125 is in Cluster 1
# Data2 slice 126 is in Cluster 1
# Data2 slice 127 is in Cluster 1
# Data2 slice 128 is in Cluster 1
# Data2 slice 129 is in Cluster 1
# Data2 slice 130 is in Cluster 1
# Data2 slice 131 is in Cluster 1
# Data2 slice 132 is in Cluster 1
# Data2 slice 133 is in Cluster 1
# Data2 slice 134 is in Cluster 1
# Data2 slice 135 is in Cluster 1
# Data2 slice 136 is in Cluster 1
# Data2 slice 137 is in Cluster 1
# Data2 slice 138 is in Cluster 1
# Data2 slice 139 is in Cluster 1
# Data2 slice 140 is in Cluster 1
# Data2 slice 141 is in Cluster 1
# Data2 slice 142 is in Cluster 1
# Data2 slice 143 is in Cluster 1
# Data2 slice 144 is in Cluster 1
# Data2 slice 145 is in Cluster 1
# Data2 slice 146 is in Cluster 1
# Data2 slice 147 is in Cluster 1
# Data2 slice 148 is in Cluster 1
# Data2 slice 149 is in Cluster 1
# Data2 slice 150 is in Cluster 1
# Data2 slice 151 is in Cluster 1
# Data2 slice 152 is in Cluster 1
# Data2 slice 153 is in Cluster 1
# Data2 slice 154 is in Cluster 1
# Data2 slice 155 is in Cluster 1
# Data2 slice 156 is in Cluster 1
# Data2 slice 157 is in Cluster 1
# Data2 slice 158 is in Cluster 1
# Data2 slice 159 is in Cluster 1
# Data2 slice 160 is in Cluster 1
# Data2 slice 161 is in Cluster 1
# Data2 slice 162 is in Cluster 1
# Data2 slice 163 is in Cluster 1
# Data2 slice 164 is in Cluster 1
# Data2 slice 165 is in Cluster 1
# Data2 slice 166 is in Cluster 1
# Data2 slice 167 is in Cluster 1

# %%
plt.plot(sData['data'][0:2000,1])
plt.plot(sTest['data'][0:2000,1])
